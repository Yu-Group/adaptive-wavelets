# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
device = 'cuda' if torch.cuda.is_available() else 'cpu'
from scipy.ndimage import gaussian_filter
import sys
from tqdm import tqdm
from functools import partial
import acd
from copy import deepcopy
sys.path.append('..')
sys.path.append('../..')
from transforms_torch import bandpass_filter
# plt.style.use('dark_background')
sys.path.append('../../dsets/mnist')
import dset
from model import Net, Net2c
from util import *
from numpy.fft import *
from torch import nn
from style import *
from captum.attr import (
    InputXGradient,
    Saliency,
    GradientShap,
    DeepLift,
    DeepLiftShap,
    IntegratedGradients,
    LayerConductance,
    NeuronConductance,
    NoiseTunnel,
)
import pickle as pkl
from torchvision import datasets, transforms
from sklearn.decomposition import NMF
import transform_wrappers
import visualize as viz
torch.manual_seed(42)
np.random.seed(42)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../../..')
# from hierarchical_dnn_interpretations.acd.scores import cd as acd
from acd_wooseok.acd.scores import cd
from acd_wooseok.acd.util import tiling_2d
from knockout_nmf import *

# %% [markdown]
# # Dataset

# %%
# load args
args = dset.get_args()
args.batch_size = int(args.batch_size/2) # half the batchsize
args.epochs = 20
args.cuda = not args.no_cuda and torch.cuda.is_available()

# load NMF object
# run NMF
# nmf = NMF(n_components=30, max_iter=1000)
# nmf.fit(X)
# pkl.dump(nmf, open('./results/nmf_30.pkl', 'wb'))
nmf = pkl.load(open('./results/nmf_30.pkl', 'rb'))

# %% [markdown]
# # Train model

# %%
basis_indx = [1, 2]
(train_loader, test_loader, interp_loader), data_dict = dataloader_nmf_knockout(args, 
                                                                 nmf, 
                                                                 basis_indx=basis_indx, 
                                                                 return_interp_loader=True,
                                                                 return_indices=True,
                                                                 task_type='interaction')

# %%
# load model
model = Net2c()
if args.cuda:
    model = model.to(device)
# model.load_state_dict(torch.load('models/nmf/net2c_{}.pth'.format(basis_indx), map_location=device))
# model = model.eval()
# dset.test(model, test_loader, args)    

# train model
for epoch in range(1, args.epochs + 1):
    model = dset.train(epoch, train_loader, model, args)
    dset.test(model, test_loader, args)

# save
# torch.save(model.state_dict(), 'mnist.model')
# Out:
# Train Epoch: 1 [48640/48751 (100%)]	Loss: 0.590125
# Test set: Average loss: 0.6239, Accuracy: 5104/8196 (62%)
#
# Train Epoch: 2 [48640/48751 (100%)]	Loss: 0.352288
# Test set: Average loss: 0.3999, Accuracy: 6861/8196 (84%)
#
# Train Epoch: 3 [48640/48751 (100%)]	Loss: 0.450972
# Test set: Average loss: 0.2936, Accuracy: 7258/8196 (89%)
#
# Train Epoch: 4 [48640/48751 (100%)]	Loss: 0.383579
# Test set: Average loss: 0.2533, Accuracy: 7358/8196 (90%)
#
# Train Epoch: 5 [48640/48751 (100%)]	Loss: 0.210027
# Test set: Average loss: 0.2189, Accuracy: 7472/8196 (91%)
#
# Train Epoch: 6 [48640/48751 (100%)]	Loss: 0.383116
# Test set: Average loss: 0.2035, Accuracy: 7570/8196 (92%)
#
# Train Epoch: 7 [48640/48751 (100%)]	Loss: 0.376861
# Test set: Average loss: 0.1842, Accuracy: 7592/8196 (93%)
#
# Train Epoch: 8 [48640/48751 (100%)]	Loss: 0.235211
# Test set: Average loss: 0.1930, Accuracy: 7503/8196 (92%)
#
# Train Epoch: 9 [48640/48751 (100%)]	Loss: 0.219199
# Test set: Average loss: 0.1780, Accuracy: 7601/8196 (93%)
#
# Train Epoch: 10 [48640/48751 (100%)]	Loss: 0.228539
# Test set: Average loss: 0.1679, Accuracy: 7645/8196 (93%)
#
# Train Epoch: 11 [48640/48751 (100%)]	Loss: 0.306058
# Test set: Average loss: 0.1537, Accuracy: 7679/8196 (94%)
#
# Train Epoch: 12 [48640/48751 (100%)]	Loss: 0.247013
# Test set: Average loss: 0.1584, Accuracy: 7623/8196 (93%)
#
# Train Epoch: 13 [48640/48751 (100%)]	Loss: 0.224075
# Test set: Average loss: 0.1634, Accuracy: 7633/8196 (93%)
#
# Train Epoch: 14 [48640/48751 (100%)]	Loss: 0.143938
# Test set: Average loss: 0.1439, Accuracy: 7716/8196 (94%)
#
# Train Epoch: 15 [48640/48751 (100%)]	Loss: 0.189939
# Test set: Average loss: 0.1448, Accuracy: 7702/8196 (94%)
#
# Train Epoch: 16 [48640/48751 (100%)]	Loss: 0.193167
# Test set: Average loss: 0.1496, Accuracy: 7657/8196 (93%)
#
# Train Epoch: 17 [48640/48751 (100%)]	Loss: 0.280767
# Test set: Average loss: 0.1421, Accuracy: 7755/8196 (95%)
#
# Train Epoch: 18 [48640/48751 (100%)]	Loss: 0.180696
# Test set: Average loss: 0.1370, Accuracy: 7706/8196 (94%)
#
# Train Epoch: 19 [48640/48751 (100%)]	Loss: 0.146092
# Test set: Average loss: 0.1337, Accuracy: 7736/8196 (94%)
#
# Train Epoch: 20 [48640/48751 (100%)]	Loss: 0.202363
# Test set: Average loss: 0.1589, Accuracy: 7640/8196 (93%)

# %% [markdown]
# # Grad scores

# %%
# gradients evaluated at the entire image
results = comp_grad_scores(model, nmf, interp_loader, data_dict, grad_mode='exact')
list_of_x = np.arange(nmf.n_components)
interp_modules = ['gradient_shap', 'ig', 'saliency', 'input_x_gradient']
viz.viz_interp_scores(list_of_x, interp_modules, results, basis_indx=basis_indx)
# Out:
#  batch index: 5

# %%
# gradients evaluated at the nmf approximation
results = comp_grad_scores(model, nmf, interp_loader, data_dict, grad_mode='approx')
list_of_x = np.arange(nmf.n_components)
interp_modules = ['gradient_shap', 'ig', 'saliency', 'input_x_gradient']
viz.viz_interp_scores(list_of_x, interp_modules, results, basis_indx=basis_indx)
# Out:
#  batch index: 5

# %% [markdown]
# # CD score

# %%
results_cd = comp_cd_scores(model, nmf, interp_loader, data_dict, cd_mode='cd', device='cuda')
# Out:
#  batch index: 5 [basis component index: 29]

# %%
results['cd'] = results_cd['cd']
list_of_x = np.arange(nmf.n_components)
interp_modules = ['gradient_shap', 'ig', 'saliency', 'input_x_gradient', 'cd']
viz.viz_interp_scores(list_of_x, interp_modules, results, basis_indx=basis_indx)
