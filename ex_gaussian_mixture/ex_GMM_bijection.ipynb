# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import random
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os,sys
opj = os.path.join
from tqdm import tqdm
import acd
from copy import deepcopy
from model_GMM import init_specific_model
from losses_GMM import BetaLoss, BtcvaeLoss
from dset_GMM import get_dataloaders
from training import Trainer
from utils import *

# %%
# GET DATALOADERS
train_loader, train_latents = get_dataloaders(n_samples_per_cluster=5000, 
                                              batch_size=100, 
                                              shuffle=True,
                                              return_latents=True)
test_loader, test_latents = get_dataloaders(n_samples_per_cluster=200, 
                                            batch_size=100, 
                                            shuffle=False,
                                            return_latents=True)

# PLOT LATENT VARIABLES
plot_2d_samples(test_latents)
plt.title('True latent variables')
plt.show()

# %%
# PREPARES MODEL
model = init_specific_model(orig_dim=10, latent_dim=2)
model = model.to(device)

# TRAINS
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
beta = 1
loss_f = BetaLoss(beta=beta)

trainer = Trainer(model, optimizer, loss_f, device=device, use_residuals=False)
trainer(train_loader, test_loader, epochs=50)

# SAVE MODEL
save_dir = "results"
os.makedirs(save_dir, exist_ok=True)

name = "beta" + str(beta)
torch.save(model.state_dict(), opj(save_dir, name))
# Out:
# ====> Epoch: 0 Average train loss: 100.5676 (Test set loss: 88.0181)
# ====> Epoch: 1 Average train loss: 81.3603 (Test set loss: 50.3889)
# ====> Epoch: 2 Average train loss: 22.8915 (Test set loss: 12.3748)
# ====> Epoch: 3 Average train loss: 13.8607 (Test set loss: 8.9770)
# ====> Epoch: 4 Average train loss: 10.7766 (Test set loss: 6.9255)
# ====> Epoch: 5 Average train loss: 8.1966 (Test set loss: 6.1106)
# ====> Epoch: 6 Average train loss: 7.2006 (Test set loss: 5.7240)
# ====> Epoch: 7 Average train loss: 6.7722 (Test set loss: 5.5302)
# ====> Epoch: 8 Average train loss: 6.5150 (Test set loss: 5.4154)
# ====> Epoch: 9 Average train loss: 6.3651 (Test set loss: 5.3194)
# ====> Epoch: 10 Average train loss: 6.2695 (Test set loss: 5.2296)
# ====> Epoch: 11 Average train loss: 6.1835 (Test set loss: 5.1813)
# ====> Epoch: 12 Average train loss: 6.0904 (Test set loss: 5.1347)
# ====> Epoch: 13 Average train loss: 6.0539 (Test set loss: 5.1121)
# ====> Epoch: 14 Average train loss: 5.9964 (Test set loss: 5.0656)
# ====> Epoch: 15 Average train loss: 5.9268 (Test set loss: 5.0320)
# ====> Epoch: 16 Average train loss: 5.8672 (Test set loss: 4.9457)
# ====> Epoch: 17 Average train loss: 5.8202 (Test set loss: 4.9082)
# ====> Epoch: 18 Average train loss: 5.7614 (Test set loss: 4.8977)
# ====> Epoch: 19 Average train loss: 5.7169 (Test set loss: 4.8789)
# ====> Epoch: 20 Average train loss: 5.6941 (Test set loss: 4.8163)
# ====> Epoch: 21 Average train loss: 5.6395 (Test set loss: 4.7748)
# ====> Epoch: 22 Average train loss: 5.6493 (Test set loss: 4.8535)
# ====> Epoch: 23 Average train loss: 5.6152 (Test set loss: 4.7449)
# ====> Epoch: 24 Average train loss: 5.6034 (Test set loss: 4.7720)
# ====> Epoch: 25 Average train loss: 5.5815 (Test set loss: 4.7692)
# ====> Epoch: 26 Average train loss: 5.5756 (Test set loss: 4.7358)
# ====> Epoch: 27 Average train loss: 5.5747 (Test set loss: 4.7602)
# ====> Epoch: 28 Average train loss: 5.5520 (Test set loss: 4.7505)
# ====> Epoch: 29 Average train loss: 5.5519 (Test set loss: 4.7709)
# ====> Epoch: 30 Average train loss: 5.5468 (Test set loss: 4.7378)
# ====> Epoch: 31 Average train loss: 5.5430 (Test set loss: 4.7876)
# ====> Epoch: 32 Average train loss: 5.5460 (Test set loss: 4.7544)
# ====> Epoch: 33 Average train loss: 5.5215 (Test set loss: 4.7403)
# ====> Epoch: 34 Average train loss: 5.5249 (Test set loss: 4.7421)
# ====> Epoch: 35 Average train loss: 5.5233 (Test set loss: 4.7190)
# ====> Epoch: 36 Average train loss: 5.5273 (Test set loss: 4.7152)
# ====> Epoch: 37 Average train loss: 5.5104 (Test set loss: 4.7189)
# ====> Epoch: 38 Average train loss: 5.5111 (Test set loss: 4.7423)
# ====> Epoch: 39 Average train loss: 5.4920 (Test set loss: 4.6966)
# ====> Epoch: 40 Average train loss: 5.5046 (Test set loss: 4.6709)
# ====> Epoch: 41 Average train loss: 5.4837 (Test set loss: 4.7154)
# ====> Epoch: 42 Average train loss: 5.4955 (Test set loss: 4.6713)
# ====> Epoch: 43 Average train loss: 5.4888 (Test set loss: 4.7167)
# ====> Epoch: 44 Average train loss: 5.4891 (Test set loss: 4.7076)
# ====> Epoch: 45 Average train loss: 5.4880 (Test set loss: 4.7133)
# ====> Epoch: 46 Average train loss: 5.4723 (Test set loss: 4.6631)
# ====> Epoch: 47 Average train loss: 5.4882 (Test set loss: 4.6851)
# ====> Epoch: 48 Average train loss: 5.4568 (Test set loss: 4.6813)
# ====> Epoch: 49 Average train loss: 5.4634 (Test set loss: 4.6934)

# %%
# EVALUATE TEST DATA
data = test_loader.dataset.data.to(device)
recon_data, latent_dist, latent_sample = model(data)

plot_2d_samples(latent_sample.detach().cpu())
plt.title('Estimated latent variables')
plt.show()

# %%
plot_2d_samples(data.detach().cpu()[:,:2])
plot_2d_samples(recon_data.detach().cpu()[:,:2])
plt.title('Original and reconstructed data after projection')
plt.show()

# %%
print('Pen: {:.8f}'.format(trainer._comp_latent_pen(latent_sample, data).item()))
# Out:
# Pen: 0.03094366

# %% [markdown]
# ###  PLOT TRAVERSALS

# %%
# GET TRAVERSAL
decoded_traversal = traversals(model, data=None)

# PROJECTION to FIRST TWO COORDINATES
decoded_traversal0 = decoded_traversal[:,:2]
plot_2d_samples(decoded_traversal0[:100])

# %%
plot_2d_samples(decoded_traversal0[100:])

# %%
# PROJECTION to SECOND TWO COORDINATES
decoded_traversal1 = decoded_traversal[:,2:4]
plot_2d_samples(decoded_traversal1[:100])

# %%
plot_2d_samples(decoded_traversal1[100:])

# %%
# PROJECTION to THIRD TWO COORDINATES
decoded_traversal2 = decoded_traversal[:,4:6]
plot_2d_samples(decoded_traversal2[:100])

# %%
plot_2d_samples(decoded_traversal2[100:])

# %%
# PROJECTION to FOURTH TWO COORDINATES
decoded_traversal3 = decoded_traversal[:,6:8]
plot_2d_samples(decoded_traversal3[:100])

# %%
plot_2d_samples(decoded_traversal3[100:])

# %%
# PROJECTION to FIFTH TWO COORDINATES
decoded_traversal4 = decoded_traversal[:,8:10]
plot_2d_samples(decoded_traversal4[:100])

# %%
plot_2d_samples(decoded_traversal4[100:])
