# %%
% load_ext autoreload
% autoreload 2
% matplotlib inline
import matplotlib.pyplot as plt
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os

opj = os.path.join

from ex_simulation import p
from awd.mdata.simulation import generate_data

# adaptive-wavelets modules

# %% [markdown]
# # load data and model

# %%
(X_train, y_train), (X_test, y_test) = generate_data(p)

# %%
x = X_train.detach().numpy().squeeze()

# %%
ax = plt.subplot(111)
plt.plot(x[0], lw=2, color='dimgrey')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xticks([])
plt.yticks([])
plt.savefig('figures/ex_sim.pdf', bbox_inches='tight')
