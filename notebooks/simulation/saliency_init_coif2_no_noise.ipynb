# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os,sys
opj = os.path.join
from copy import deepcopy
from tqdm import tqdm

from ex_simulation import p
from dset import get_dataloader, load_pretrained_model

# adaptive-wavelets modules
from losses import get_loss_f
from train import Trainer
from evaluate import Validator
from transform1d import DWT1d
from utils import get_1dfilts, get_wavefun
from wave_attributions import Attributer
from visualize import cshow, plot_1dfilts, plot_1dreconstruct, plot_wavefun

# %% [markdown]
# # load data and model

# %%
# load data and model
train_loader, test_loader = get_dataloader(p.data_path,
                                           batch_size=p.batch_size)

model = load_pretrained_model(p.model_path)

# %% [markdown]
# # define wavelet

# %%
# wavelet transform 
wt = DWT1d(wave='coif2', mode='zero', J=p.J, init_factor=1, noise_factor=0, const_factor=0).to(device)

# get image
data = iter(test_loader).next()[0].to(device)
data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 1d wavelet filters
filt = get_1dfilts(wt)
# Out:
# Reconstruction error=0.00000

# %%
# plot original and reconstruction images
plot_1dreconstruct(data, recon)

# %%
# original wavelet
filt = get_1dfilts(wt)
phi, psi, x = get_wavefun(wt)

plot_1dfilts(filt, is_title=True, figsize=(2,2))

plot_wavefun((phi, psi, x), is_title=True, figsize=(3,1))

# %% [markdown]
# # optimize filter

# %%
# train
params = list(wt.parameters())
optimizer = torch.optim.Adam(params, lr=0.001)
loss_f = get_loss_f(lamlSum=1, lamhSum=1, lamL2norm=1, lamCMF=1, lamConv=1, lamL1wave=0.0001, lamL1attr=0.03)
trainer = Trainer(model, wt, optimizer, loss_f, target=0, 
                  use_residuals=True, attr_methods='Saliency', device=device, n_print=2)

# %%
trainer(train_loader, epochs=50)
# Out:
# Starting Training Loop...
# Train Epoch: 0 [49900/50000 (100%)]	Loss: 0.083031
# ====> Epoch: 0 Average train loss: 0.0823
# Train Epoch: 2 [49900/50000 (100%)]	Loss: 0.040748
# ====> Epoch: 2 Average train loss: 0.0621
# Train Epoch: 4 [49900/50000 (100%)]	Loss: 0.040787
# ====> Epoch: 4 Average train loss: 0.0406
# Train Epoch: 6 [49900/50000 (100%)]	Loss: 0.040555
# ====> Epoch: 6 Average train loss: 0.0406
# Train Epoch: 8 [49900/50000 (100%)]	Loss: 0.040236
# ====> Epoch: 8 Average train loss: 0.0406
# Train Epoch: 10 [49900/50000 (100%)]	Loss: 0.040440
# ====> Epoch: 10 Average train loss: 0.0406
# Train Epoch: 12 [49900/50000 (100%)]	Loss: 0.040961
# ====> Epoch: 12 Average train loss: 0.0406
# Train Epoch: 14 [49900/50000 (100%)]	Loss: 0.040175
# ====> Epoch: 14 Average train loss: 0.0406
# Train Epoch: 16 [49900/50000 (100%)]	Loss: 0.040449
# ====> Epoch: 16 Average train loss: 0.0406
# Train Epoch: 18 [49900/50000 (100%)]	Loss: 0.040679
# ====> Epoch: 18 Average train loss: 0.0406
# Train Epoch: 20 [49900/50000 (100%)]	Loss: 0.040729
# ====> Epoch: 20 Average train loss: 0.0406
# Train Epoch: 22 [49900/50000 (100%)]	Loss: 0.040742
# ====> Epoch: 22 Average train loss: 0.0406
# Train Epoch: 24 [49900/50000 (100%)]	Loss: 0.041133
# ====> Epoch: 24 Average train loss: 0.0406
# Train Epoch: 26 [49900/50000 (100%)]	Loss: 0.040579
# ====> Epoch: 26 Average train loss: 0.0406
# Train Epoch: 28 [49900/50000 (100%)]	Loss: 0.040535
# ====> Epoch: 28 Average train loss: 0.0406
# Train Epoch: 30 [49900/50000 (100%)]	Loss: 0.041196
# ====> Epoch: 30 Average train loss: 0.0406
# Train Epoch: 32 [49900/50000 (100%)]	Loss: 0.040959
# ====> Epoch: 32 Average train loss: 0.0406
# Train Epoch: 34 [49900/50000 (100%)]	Loss: 0.039986
# ====> Epoch: 34 Average train loss: 0.0406
# Train Epoch: 36 [49900/50000 (100%)]	Loss: 0.040797
# ====> Epoch: 36 Average train loss: 0.0406
# Train Epoch: 38 [49900/50000 (100%)]	Loss: 0.040606
# ====> Epoch: 38 Average train loss: 0.0406
# Train Epoch: 40 [49900/50000 (100%)]	Loss: 0.040159
# ====> Epoch: 40 Average train loss: 0.0406
# Train Epoch: 42 [49900/50000 (100%)]	Loss: 0.040313
# ====> Epoch: 42 Average train loss: 0.0406
# Train Epoch: 44 [49900/50000 (100%)]	Loss: 0.040183
# ====> Epoch: 44 Average train loss: 0.0406
# Train Epoch: 46 [49900/50000 (100%)]	Loss: 0.040278
# ====> Epoch: 46 Average train loss: 0.0406
# Train Epoch: 48 [49900/50000 (100%)]	Loss: 0.040721
# ====> Epoch: 48 Average train loss: 0.0406

# %%
plt.plot(np.log(trainer.train_losses))
plt.xlabel("epochs")
plt.ylabel("log train loss")
plt.title('Log-train loss vs epochs')
plt.show()

# %%
data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 2d wavelet filters
filt = get_1dfilts(wt)
# Out:
# Reconstruction error=0.00000

# %%
# plot original and reconstruction images
plot_1dreconstruct(data, recon)

# %% [markdown]
# # test error

# %%
# validator 
validator = Validator(model, test_loader)
rec_loss, lsum_loss, hsum_loss, L2norm_loss, CMF_loss, conv_loss, L1wave_loss, L1saliency_loss, L1inputxgrad_loss = validator(wt, target=0)

# original wavelet transform
wt_o = DWT1d(wave='db5', mode='zero', J=4, init_factor=1, noise_factor=0).to(device)
rec_loss_o, lsum_loss_o, hsum_loss_o, L2norm_loss_o, CMF_loss_o, conv_loss_o, L1wave_loss_o, L1saliency_loss_o, L1inputxgrad_loss_o = validator(wt_o, target=0)

print("\n\n \t Original filter:Reconstruction Error={:.5f} lsum loss={:.5f} hsum loss={:.5f} L2norm loss={:.5f} CMF loss={:.5f} conv loss={:.5f} L1wave loss={:.5f} L1saliency loss={:.5f} L1inputxgrad loss={:.5f} \n \
        Adaptive filter:Reconstruction Error={:.5f} lsum loss={:.5f} hsum loss={:.5f} L2norm loss={:.5f} CMF loss={:.5f} conv loss={:.5f} L1wave loss={:.5f} L1saliency loss={:.5f} L1inputxgrad loss={:.5f}"\
          .format(rec_loss_o, lsum_loss_o, hsum_loss_o, L2norm_loss_o, CMF_loss_o, conv_loss_o, L1wave_loss_o, L1saliency_loss_o, L1inputxgrad_loss_o, 
                  rec_loss, lsum_loss, hsum_loss, L2norm_loss, CMF_loss, conv_loss, L1wave_loss, L1saliency_loss, L1inputxgrad_loss))
# Out:
#  	 Original filter:Reconstruction Error=0.00000 lsum loss=0.00000 hsum loss=0.00000 L2norm loss=0.00000 CMF loss=0.00000 conv loss=0.00000 L1wave loss=10.85556 L1saliency loss=1.32234 L1inputxgrad loss=1.03428
#          Adaptive filter:Reconstruction Error=0.00000 lsum loss=0.00000 hsum loss=0.00000 L2norm loss=0.00000 CMF loss=0.00000 conv loss=0.00000 L1wave loss=10.85577 L1saliency loss=1.31894 L1inputxgrad loss=1.03180

# %%
# original wavelet
filt = get_1dfilts(wt)
filt_o = get_1dfilts(wt_o)
phi, psi, x = get_wavefun(wt)
phi_o, psi_o, x_o = get_wavefun(wt_o)

plot_1dfilts(filt, is_title=True, figsize=(2,2))
plot_1dfilts(filt_o, is_title=True, figsize=(2,2))

plot_wavefun((phi, psi, x), is_title=True, figsize=(3,1))
plot_wavefun((phi_o, psi_o, x_o), is_title=True, figsize=(3,1))

# %%
# sys.path.append('../../lib/trim')
# from trim import TrimModel
# from utils import tuple_to_tensor, tensor_to_tuple

# mt = TrimModel(model, wt.inverse, use_residuals=True)    
# attributer = Attributer(mt, attr_methods='Saliency', device='cuda')

# b = torch.tensor([]).to(device)
# c = torch.tensor([]).to(device)
# for data, _ in test_loader:
#     data = data.to(device)
#     data_t = wt(data)
#     attributions = attributer(data_t, target=0, additional_forward_args=deepcopy(data))
#     y, _ = tuple_to_tensor(data_t)
#     b = torch.cat((y,b), dim=0)     
#     z, _ = tuple_to_tensor(attributions)
#     c = torch.cat((z,c), dim=0)
# b = b.reshape(-1)
# c = c.reshape(-1)
# sort_indexes = torch.argsort(b, dim=0, descending=False)          
    
# plt.plot(b[sort_indexes].detach().cpu())
# plt.show()

# plt.plot(c[sort_indexes].detach().cpu())
# plt.show()
