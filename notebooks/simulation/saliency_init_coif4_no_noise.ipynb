# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os,sys
opj = os.path.join
from copy import deepcopy
from tqdm import tqdm

from ex_simulation import p
from dset import get_dataloader, load_pretrained_model

# adaptive-wavelets modules
from losses import get_loss_f
from train import Trainer
from evaluate import Validator
from transform1d import DWT1d
from utils import get_1dfilts, get_wavefun
from wave_attributions import Attributer
from visualize import cshow, plot_1dfilts, plot_1dreconstruct, plot_wavefun

# %% [markdown]
# # load data and model

# %%
# load data and model
train_loader, test_loader = get_dataloader(p.data_path,
                                           batch_size=p.batch_size)

model = load_pretrained_model(p.model_path)

# %% [markdown]
# # define wavelet

# %%
# wavelet transform 
wt = DWT1d(wave='sym4', mode='zero', J=p.J, init_factor=1, noise_factor=0, const_factor=0).to(device)

# get image
data = iter(test_loader).next()[0].to(device)
data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 1d wavelet filters
filt = get_1dfilts(wt)
# Out:
# Reconstruction error=0.00000

# %%
# plot original and reconstruction images
plot_1dreconstruct(data, recon)

# %%
# original wavelet
filt = get_1dfilts(wt)
phi, psi, x = get_wavefun(wt)

plot_1dfilts(filt, is_title=True, figsize=(2,2))

plot_wavefun((phi, psi, x), is_title=True, figsize=(3,1))

# %% [markdown]
# # optimize filter

# %%
# train
params = list(wt.parameters())
optimizer = torch.optim.Adam(params, lr=0.001)
loss_f = get_loss_f(lamlSum=1, lamhSum=1, lamL2norm=1, lamCMF=1, lamConv=1, lamL1wave=0.001, lamL1attr=0.001)
trainer = Trainer(model, wt, optimizer, loss_f, target=0, 
                  use_residuals=True, attr_methods='Saliency', device=device, n_print=2)

# %%
trainer(train_loader, epochs=20)
# Out:
# Starting Training Loop...
# Train Epoch: 0 [49900/50000 (100%)]	Loss: 0.013218
# ====> Epoch: 0 Average train loss: 0.0135
# Train Epoch: 2 [49900/50000 (100%)]	Loss: 0.013270
# ====> Epoch: 2 Average train loss: 0.0133
# Train Epoch: 4 [49900/50000 (100%)]	Loss: 0.013177
# ====> Epoch: 4 Average train loss: 0.0133
# Train Epoch: 6 [1100/50000 (2%)]	Loss: 0.013332
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-733f7c01dfb5> in <module>
# ----> 1 trainer(train_loader, epochs=20)
#
# ~/adaptive-wavelets/src/adaptive_wavelets/train.py in __call__(self, train_loader, test_loader, epochs)
#      73
#      74             else:
# ---> 75                 mean_epoch_loss = self._train_epoch(train_loader, epoch)
#      76                 if epoch % self.n_print == 0:
#      77                     print('\n====> Epoch: {} Average train loss: {:.4f}'.format(epoch, mean_epoch_loss))
#
# ~/adaptive-wavelets/src/adaptive_wavelets/train.py in _train_epoch(self, data_loader, epoch)
#      96         epoch_loss = 0.
#      97         for batch_idx, (data, _) in enumerate(data_loader):
# ---> 98             iter_loss = self._train_iteration(data)
#      99             epoch_loss += iter_loss
#     100             if epoch % self.n_print == 0:
#
# ~/adaptive-wavelets/src/adaptive_wavelets/train.py in _train_iteration(self, data)
#     126         # TRIM score
#     127         with torch.backends.cudnn.flags(enabled=False):
# --> 128             attributions = self.attributer(data_t, target=self.target, additional_forward_args=deepcopy(data)) if self.loss_f.lamL1attr > 0 else None
#     129         # loss
#     130         loss = self.loss_f(self.w_transform, data, recon_data, data_t, attributions)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/adaptive-wavelets/src/adaptive_wavelets/wave_attributions.py in forward(self, x, target, additional_forward_args)
#      29             attributions = self.IntegratedGradient(x, target, additional_forward_args)
#      30         elif self.attr_methods == 'Saliency':
# ---> 31             attributions = self.Saliency(x, target, additional_forward_args)
#      32         else:
#      33             raise ValueError
#
# ~/adaptive-wavelets/src/adaptive_wavelets/wave_attributions.py in Saliency(self, x, target, additional_forward_args)
#      47         outputs = self.mt(x, additional_forward_args)[:,target]
#      48         if self.is_train:
# ---> 49             grads = torch.autograd.grad(torch.unbind(outputs), x, create_graph=True)
#      50         else:
#      51             grads = torch.autograd.grad(torch.unbind(outputs), x)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:

# %%
plt.plot(np.log(trainer.train_losses))
plt.xlabel("epochs")
plt.ylabel("log train loss")
plt.title('Log-train loss vs epochs')
plt.show()

# %%
data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 2d wavelet filters
filt = get_1dfilts(wt)
# Out:
# Reconstruction error=0.00000

# %%
# plot original and reconstruction images
plot_1dreconstruct(data, recon)

# %% [markdown]
# # test error

# %%
# validator 
validator = Validator(model, test_loader)
rec_loss, lsum_loss, hsum_loss, L2norm_loss, CMF_loss, conv_loss, L1wave_loss, L1saliency_loss, L1inputxgrad_loss = validator(wt, target=0)

# original wavelet transform
wt_o = DWT1d(wave='sym4', mode='zero', J=4, init_factor=1, noise_factor=0).to(device)
rec_loss_o, lsum_loss_o, hsum_loss_o, L2norm_loss_o, CMF_loss_o, conv_loss_o, L1wave_loss_o, L1saliency_loss_o, L1inputxgrad_loss_o = validator(wt_o, target=0)

print("\n\n \t Original filter:Reconstruction Error={:.5f} lsum loss={:.5f} hsum loss={:.5f} L2norm loss={:.5f} CMF loss={:.5f} conv loss={:.5f} L1wave loss={:.5f} L1saliency loss={:.5f} L1inputxgrad loss={:.5f} \n \
        Adaptive filter:Reconstruction Error={:.5f} lsum loss={:.5f} hsum loss={:.5f} L2norm loss={:.5f} CMF loss={:.5f} conv loss={:.5f} L1wave loss={:.5f} L1saliency loss={:.5f} L1inputxgrad loss={:.5f}"\
          .format(rec_loss_o, lsum_loss_o, hsum_loss_o, L2norm_loss_o, CMF_loss_o, conv_loss_o, L1wave_loss_o, L1saliency_loss_o, L1inputxgrad_loss_o, 
                  rec_loss, lsum_loss, hsum_loss, L2norm_loss, CMF_loss, conv_loss, L1wave_loss, L1saliency_loss, L1inputxgrad_loss))
# Out:
#  	 Original filter:Reconstruction Error=0.00000 lsum loss=0.00000 hsum loss=0.00000 L2norm loss=0.00000 CMF loss=0.00000 conv loss=0.00000 L1wave loss=10.60672 L1saliency loss=2.57697 L1inputxgrad loss=2.01965
#          Adaptive filter:Reconstruction Error=0.00000 lsum loss=0.00000 hsum loss=0.00000 L2norm loss=0.00000 CMF loss=0.00000 conv loss=0.00000 L1wave loss=10.58285 L1saliency loss=2.62812 L1inputxgrad loss=2.06314

# %%
# original wavelet
filt = get_1dfilts(wt)
filt_o = get_1dfilts(wt_o)
phi, psi, x = get_wavefun(wt)
phi_o, psi_o, x_o = get_wavefun(wt_o)

plot_1dfilts(filt, is_title=True, figsize=(2,2))
plot_1dfilts(filt_o, is_title=True, figsize=(2,2))

plot_wavefun((phi, psi, x), is_title=True, figsize=(3,1))
plot_wavefun((phi_o, psi_o, x_o), is_title=True, figsize=(3,1))

# %%
# sys.path.append('../../lib/trim')
# from trim import TrimModel
# from utils import tuple_to_tensor, tensor_to_tuple

# mt = TrimModel(model, wt.inverse, use_residuals=True)    
# attributer = Attributer(mt, attr_methods='Saliency', device='cuda')

# b = torch.tensor([]).to(device)
# c = torch.tensor([]).to(device)
# for data, _ in test_loader:
#     data = data.to(device)
#     data_t = wt(data)
#     attributions = attributer(data_t, target=0, additional_forward_args=deepcopy(data))
#     y, _ = tuple_to_tensor(data_t)
#     b = torch.cat((y,b), dim=0)     
#     z, _ = tuple_to_tensor(attributions)
#     c = torch.cat((z,c), dim=0)
# b = b.reshape(-1)
# c = c.reshape(-1)
# sort_indexes = torch.argsort(b, dim=0, descending=False)          
    
# plt.plot(b[sort_indexes].detach().cpu())
# plt.show()

# plt.plot(c[sort_indexes].detach().cpu())
# plt.show()
