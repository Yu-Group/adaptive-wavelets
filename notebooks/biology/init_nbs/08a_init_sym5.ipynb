# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import random

import numpy as np
import torch
import matplotlib.pyplot as plt
opj = os.path.join
import pickle as pkl

from ex_biology import p

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# adaptive-wavelets modules
import awd
from awd.mdata.biology import get_dataloader, load_pretrained_model
from awd.utils import get_wavefun, get_1dfilts
from awd.visualize import plot_1dfilts, plot_wavefun
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
p.wave = 'sym5'
p.J = 4
p.mode = 'zero'
p.init_factor = 1
p.noise_factor = 0
p.const_factor = 0
p.num_epochs = 100
p.attr_methods = 'Saliency'

lamWaveloss = 1
p.lamlSum = lamWaveloss
p.lamhSum = lamWaveloss
p.lamL2sum = lamWaveloss
p.lamCMF = lamWaveloss
p.lamConv = lamWaveloss
p.lamL1wave = 0
p.lamL1attr = 0.5
p.target = 0

# %%
# load data and model
train_loader, test_loader = get_dataloader(p.data_path,
                                           batch_size=p.batch_size,
                                           is_continuous=p.is_continuous)

model = load_pretrained_model(p.model_path, device=device)

# prepare model
random.seed(p.seed)
np.random.seed(p.seed)
torch.manual_seed(p.seed)

wt = awd.DWT1d(wave=p.wave, mode=p.mode, J=p.J,
               init_factor=p.init_factor,
               noise_factor=p.noise_factor,
               const_factor=p.const_factor).to(device)
wt.train()

# train
params = list(wt.parameters())
optimizer = torch.optim.Adam(params, lr=p.lr)
loss_f = awd.get_loss_f(lamlSum=p.lamlSum, lamhSum=p.lamhSum, lamL2norm=p.lamL2norm, lamCMF=p.lamCMF,
                        lamConv=p.lamConv, lamL1wave=p.lamL1wave, lamL1attr=p.lamL1attr)
trainer = awd.Trainer(model, wt, optimizer, loss_f, target=p.target,
                      use_residuals=True, attr_methods=p.attr_methods, device=device, n_print=5)

# %%
# run
trainer(train_loader, epochs=p.num_epochs)
# Out:
# Starting Training Loop...
# Train Epoch: 0 [1044/2936 (97%)]	Loss: 0.230232
# ====> Epoch: 0 Average train loss: 0.2142
# Train Epoch: 5 [1044/2936 (97%)]	Loss: 0.176607
# ====> Epoch: 5 Average train loss: 0.2051
# Train Epoch: 10 [1044/2936 (97%)]	Loss: 0.187020
# ====> Epoch: 10 Average train loss: 0.2040
# Train Epoch: 15 [1044/2936 (97%)]	Loss: 0.191692
# ====> Epoch: 15 Average train loss: 0.2026
# Train Epoch: 20 [1044/2936 (97%)]	Loss: 0.220343
# ====> Epoch: 20 Average train loss: 0.2019
# Train Epoch: 25 [1044/2936 (97%)]	Loss: 0.198246
# ====> Epoch: 25 Average train loss: 0.1995
# Train Epoch: 30 [1044/2936 (97%)]	Loss: 0.183061
# ====> Epoch: 30 Average train loss: 0.1977
# Train Epoch: 35 [1044/2936 (97%)]	Loss: 0.207498
# ====> Epoch: 35 Average train loss: 0.1970
# Train Epoch: 40 [1044/2936 (97%)]	Loss: 0.203899
# ====> Epoch: 40 Average train loss: 0.1957
# Train Epoch: 45 [1044/2936 (97%)]	Loss: 0.215306
# ====> Epoch: 45 Average train loss: 0.1949
# Train Epoch: 50 [1044/2936 (97%)]	Loss: 0.171770
# ====> Epoch: 50 Average train loss: 0.1931
# Train Epoch: 55 [1044/2936 (97%)]	Loss: 0.224228
# ====> Epoch: 55 Average train loss: 0.1936
# Train Epoch: 60 [1044/2936 (97%)]	Loss: 0.197780
# ====> Epoch: 60 Average train loss: 0.1925
# Train Epoch: 65 [1044/2936 (97%)]	Loss: 0.223465
# ====> Epoch: 65 Average train loss: 0.1922
# Train Epoch: 70 [1044/2936 (97%)]	Loss: 0.172849
# ====> Epoch: 70 Average train loss: 0.1911
# Train Epoch: 75 [1044/2936 (97%)]	Loss: 0.213112
# ====> Epoch: 75 Average train loss: 0.1912
# Train Epoch: 80 [1044/2936 (97%)]	Loss: 0.201087
# ====> Epoch: 80 Average train loss: 0.1907
# Train Epoch: 85 [1044/2936 (97%)]	Loss: 0.178373
# ====> Epoch: 85 Average train loss: 0.1899
# Train Epoch: 90 [1044/2936 (97%)]	Loss: 0.181086
# ====> Epoch: 90 Average train loss: 0.1896
# Train Epoch: 95 [1044/2936 (97%)]	Loss: 0.199772
# ====> Epoch: 95 Average train loss: 0.1897

# %%
plt.plot(np.log(trainer.train_losses))
plt.xlabel("epochs")
plt.ylabel("log train loss")
plt.title('Log-train loss vs epochs')
plt.show()

# %%
print('calculating losses and metric...')
model.train()  # cudnn RNN backward can only be called in training mode
validator = awd.Validator(model, test_loader)
rec_loss, lsum_loss, hsum_loss, L2norm_loss, CMF_loss, conv_loss, L1wave_loss, L1saliency_loss, L1inputxgrad_loss = validator(
    wt, target=p.target)
print("Recon={:.5f}\n lsum={:.5f}\n hsum={:.5f}\n L2norm={:.5f}\n CMF={:.5f}\n conv={:.5f}\n L1wave={:.5f}\n Saliency={:.5f}\n Inputxgrad={:.5f}\n".format(rec_loss,
                                      lsum_loss,
                                      hsum_loss,
                                      L2norm_loss,
                                      CMF_loss,
                                      conv_loss,
                                      L1wave_loss,
                                      L1saliency_loss,
                                      L1inputxgrad_loss))
# Out:
# calculating losses and metric...
# Recon=0.00018
#  lsum=0.00000
#  hsum=0.00031
#  L2norm=0.00000
#  CMF=0.00000
#  conv=0.00000
#  L1wave=4.12179
#  Saliency=0.36728
#  Inputxgrad=0.28381

# %%
filt = get_1dfilts(wt)
phi, psi, x = get_wavefun(wt)

plot_1dfilts(filt, is_title=True, figsize=(2,2))
plot_wavefun((phi, psi, x), is_title=True, figsize=(2,1))
