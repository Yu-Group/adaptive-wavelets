# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import torch
import random
import sys
import matplotlib.pyplot as plt
device = 'cuda' if torch.cuda.is_available() else 'cpu'

from ex_biology import p
sys.path.append('preprocessing')
import data
import neural_networks

# adaptive-wavelets modules
sys.path.append('../..')
from src import adaptive_wavelets
from src.dsets.biology import dset
from src.visualize import cshow, plot_1dfilts, plot_1dreconstruct, plot_wavefun

# %%
# parameters for initialization
p.wave = 'db5'
p.J = 4
p.mode = 'zero'
p.init_factor = 1
p.noise_factor = 0    
p.const_factor = 0
p.num_epochs = 100
p.lamL1wave = 0.0001
p.lamL1attr = 0.2

# %%
# load data and model
train_loader, test_loader = dset.get_dataloader(p.data_path, 
                                                batch_size=p.batch_size,
                                                is_continuous=p.is_continuous)   

model = dset.load_pretrained_model(p.model_path, device=device)  

# prepare model
random.seed(p.seed)
np.random.seed(p.seed)
torch.manual_seed(p.seed)  

wt = adaptive_wavelets.DWT1d(wave=p.wave, mode=p.mode, J=p.J, 
                             init_factor=p.init_factor, 
                             noise_factor=p.noise_factor,
                             const_factor=p.const_factor).to(device)
wt.train()

# train
params = list(wt.parameters())
optimizer = torch.optim.Adam(params, lr=p.lr)
loss_f = adaptive_wavelets.get_loss_f(lamlSum=p.lamlSum, lamhSum=p.lamhSum, lamL2norm=p.lamL2norm, 
                                      lamCMF=p.lamCMF, lamConv=p.lamConv, lamL1wave=p.lamL1wave, lamL1attr=p.lamL1attr)
trainer = adaptive_wavelets.Trainer(model, wt, optimizer, loss_f, target=p.target, 
                                    use_residuals=True, attr_methods=p.attr_methods, 
                                    device=device, n_print=5)

# %%
# run
trainer(train_loader, epochs=p.num_epochs)

plt.plot(np.log(trainer.train_losses))
plt.xlabel("epochs")
plt.ylabel("log train loss")
plt.title('Log-train loss vs epochs')
plt.show()
# Out:
# Starting Training Loop...
# Train Epoch: 0 [1044/2936 (97%)]	Loss: 0.076334
# ====> Epoch: 0 Average train loss: 0.0769
# Train Epoch: 5 [1044/2936 (97%)]	Loss: 0.078562
# ====> Epoch: 5 Average train loss: 0.0769
# Train Epoch: 10 [1044/2936 (97%)]	Loss: 0.083100
# ====> Epoch: 10 Average train loss: 0.0770
# Train Epoch: 15 [1044/2936 (97%)]	Loss: 0.068297
# ====> Epoch: 15 Average train loss: 0.0766
# Train Epoch: 20 [1044/2936 (97%)]	Loss: 0.070208
# ====> Epoch: 20 Average train loss: 0.0767
# Train Epoch: 25 [1044/2936 (97%)]	Loss: 0.073923
# ====> Epoch: 25 Average train loss: 0.0767
# Train Epoch: 30 [1044/2936 (97%)]	Loss: 0.076895
# ====> Epoch: 30 Average train loss: 0.0768
# Train Epoch: 35 [1044/2936 (97%)]	Loss: 0.079906
# ====> Epoch: 35 Average train loss: 0.0769
# Train Epoch: 40 [1044/2936 (97%)]	Loss: 0.076788
# ====> Epoch: 40 Average train loss: 0.0769
# Train Epoch: 45 [1044/2936 (97%)]	Loss: 0.076433
# ====> Epoch: 45 Average train loss: 0.0768
# Train Epoch: 50 [1044/2936 (97%)]	Loss: 0.086858
# ====> Epoch: 50 Average train loss: 0.0770
# Train Epoch: 55 [1044/2936 (97%)]	Loss: 0.078303
# ====> Epoch: 55 Average train loss: 0.0769
# Train Epoch: 60 [1044/2936 (97%)]	Loss: 0.084553
# ====> Epoch: 60 Average train loss: 0.0769
# Train Epoch: 65 [1044/2936 (97%)]	Loss: 0.075576
# ====> Epoch: 65 Average train loss: 0.0769
# Train Epoch: 70 [1044/2936 (97%)]	Loss: 0.080775
# ====> Epoch: 70 Average train loss: 0.0768
# Train Epoch: 75 [1044/2936 (97%)]	Loss: 0.074744
# ====> Epoch: 75 Average train loss: 0.0767
# Train Epoch: 80 [1044/2936 (97%)]	Loss: 0.072072
# ====> Epoch: 80 Average train loss: 0.0766
# Train Epoch: 85 [1044/2936 (97%)]	Loss: 0.091992
# ====> Epoch: 85 Average train loss: 0.0771
# Train Epoch: 90 [1044/2936 (97%)]	Loss: 0.067800
# ====> Epoch: 90 Average train loss: 0.0766
# Train Epoch: 95 [1044/2936 (97%)]	Loss: 0.071290
# ====> Epoch: 95 Average train loss: 0.0766

# %%
data = iter(test_loader).next()[0].to(device)
data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 2d wavelet filters
filt = adaptive_wavelets.get_1dfilts(wt)
phi, psi, x = adaptive_wavelets.get_wavefun(wt)

plot_1dfilts(filt, is_title=True, figsize=(2,2))
plot_wavefun((phi, psi, x), is_title=True, figsize=(3,1))
# Out:
# Reconstruction error=0.00010
