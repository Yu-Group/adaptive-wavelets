# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os,sys
opj = os.path.join
from copy import deepcopy
import pickle as pkl
from tqdm import tqdm

from sim_biology import p, load_dataloader_and_pretrained_model
# adaptive-wavelets modules
sys.path.append('../../src')
sys.path.append('../../src/adaptive_wavelets')
from losses import get_loss_f
from train import Trainer, Validator
from transform1d import DWT1d
from utils import get_1dfilts
from wave_attributions import Attributer
from visualize import cshow, plot_1dreconstruct, plot_1dfilts

# %% [markdown]
# ## load data and model

# %%
# get dataloader and model
(train_loader, test_loader), model = load_dataloader_and_pretrained_model(p)

# %%
# get image
data = iter(test_loader).next()[0].to(device)

# wavelet transform 
wt = DWT1d(wave='db5', mode='symmetric', J=5, init_factor=0, noise_factor=0.1).to(device)

data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 1d wavelet filters
filt = get_1dfilts(wt)
# Out:
# Reconstruction error=39.94681

# %%
# plot original and reconstruction images
plot_1dreconstruct(data, recon)

# %%
# plot wavelet filters
plot_1dfilts(filt, figsize=(1,1))

# %% [markdown]
# ## optimize filter

# %%
# train
params = list(wt.parameters())
optimizer = torch.optim.Adam(params, lr=0.005)
loss_f = get_loss_f(lamSum=10, lamL2norm=10, lamCMF=10, lamL1wave=1, lamL1attr=0.)
trainer = Trainer(model, wt, Attributer, optimizer, loss_f, target=0, attr_methods='Saliency', device=device, n_print=50)

# %%
trainer(train_loader, epochs=2000)
# Out:
# Starting Training Loop...
# Train Epoch: 0 [1044/2936 (97%)]	Loss: 33.738453
# ====> Epoch: 0 Average train loss: 49.2075
# Train Epoch: 50 [1044/2936 (97%)]	Loss: 8.2901362
# ====> Epoch: 50 Average train loss: 9.5480
# Train Epoch: 100 [1044/2936 (97%)]	Loss: 9.2910395
# ====> Epoch: 100 Average train loss: 9.4240
# Train Epoch: 150 [1044/2936 (97%)]	Loss: 9.5596769
# ====> Epoch: 150 Average train loss: 9.4311
# Train Epoch: 200 [1044/2936 (97%)]	Loss: 9.4575421
# ====> Epoch: 200 Average train loss: 9.4325
# Train Epoch: 250 [1044/2936 (97%)]	Loss: 9.2077477
# ====> Epoch: 250 Average train loss: 9.4221
# Train Epoch: 300 [1044/2936 (97%)]	Loss: 9.181414
# ====> Epoch: 300 Average train loss: 9.4239
# Train Epoch: 350 [1044/2936 (97%)]	Loss: 10.587307
# ====> Epoch: 350 Average train loss: 9.4591
# Train Epoch: 400 [1044/2936 (97%)]	Loss: 10.230113
# ====> Epoch: 400 Average train loss: 9.4427
# Train Epoch: 450 [1044/2936 (97%)]	Loss: 9.9133305
# ====> Epoch: 450 Average train loss: 9.4367
# Train Epoch: 500 [1044/2936 (97%)]	Loss: 9.7720788
# ====> Epoch: 500 Average train loss: 9.4324
# Train Epoch: 550 [1044/2936 (97%)]	Loss: 9.8570335
# ====> Epoch: 550 Average train loss: 9.4339
# Train Epoch: 600 [1044/2936 (97%)]	Loss: 8.8274474
# ====> Epoch: 600 Average train loss: 9.4145
# Train Epoch: 650 [1044/2936 (97%)]	Loss: 9.7396052
# ====> Epoch: 650 Average train loss: 9.4328
# Train Epoch: 700 [1044/2936 (97%)]	Loss: 9.1322672
# ====> Epoch: 700 Average train loss: 9.4217
# Train Epoch: 750 [1044/2936 (97%)]	Loss: 11.444050
# ====> Epoch: 750 Average train loss: 9.4691
# Train Epoch: 800 [1044/2936 (97%)]	Loss: 8.2939956
# ====> Epoch: 800 Average train loss: 9.4045
# Train Epoch: 850 [1044/2936 (97%)]	Loss: 8.6389505
# ====> Epoch: 850 Average train loss: 9.4128
# Train Epoch: 900 [1044/2936 (97%)]	Loss: 8.9389960
# ====> Epoch: 900 Average train loss: 9.4155
# Train Epoch: 950 [1044/2936 (97%)]	Loss: 9.1666736
# ====> Epoch: 950 Average train loss: 9.4200
# Train Epoch: 1000 [1044/2936 (97%)]	Loss: 9.4745741
# ====> Epoch: 1000 Average train loss: 9.4269
# Train Epoch: 1050 [1044/2936 (97%)]	Loss: 8.5573893
# ====> Epoch: 1050 Average train loss: 9.4115
# Train Epoch: 1100 [1044/2936 (97%)]	Loss: 9.583611
# ====> Epoch: 1100 Average train loss: 9.4286
# Train Epoch: 1150 [1044/2936 (97%)]	Loss: 9.8956209
# ====> Epoch: 1150 Average train loss: 9.4365
# Train Epoch: 1200 [1044/2936 (97%)]	Loss: 8.8323965
# ====> Epoch: 1200 Average train loss: 9.4142
# Train Epoch: 1250 [1044/2936 (97%)]	Loss: 9.782081
# ====> Epoch: 1250 Average train loss: 9.4341
# Train Epoch: 1300 [1044/2936 (97%)]	Loss: 9.799728
# ====> Epoch: 1300 Average train loss: 9.4352
# Train Epoch: 1350 [1044/2936 (97%)]	Loss: 10.614048
# ====> Epoch: 1350 Average train loss: 9.4505
# Train Epoch: 1400 [1044/2936 (97%)]	Loss: 8.6537653
# ====> Epoch: 1400 Average train loss: 9.4176
# Train Epoch: 1450 [1044/2936 (97%)]	Loss: 8.5465564
# ====> Epoch: 1450 Average train loss: 9.4077
# Train Epoch: 1500 [1044/2936 (97%)]	Loss: 10.151920
# ====> Epoch: 1500 Average train loss: 9.4411
# Train Epoch: 1550 [1044/2936 (97%)]	Loss: 9.4466475
# ====> Epoch: 1550 Average train loss: 9.4262
# Train Epoch: 1600 [1044/2936 (97%)]	Loss: 9.7338089
# ====> Epoch: 1600 Average train loss: 9.4335
# Train Epoch: 1650 [1044/2936 (97%)]	Loss: 9.7553048
# ====> Epoch: 1650 Average train loss: 9.4359
# Train Epoch: 1700 [1044/2936 (97%)]	Loss: 8.572063
# ====> Epoch: 1700 Average train loss: 9.4115
# Train Epoch: 1750 [1044/2936 (97%)]	Loss: 9.554344
# ====> Epoch: 1750 Average train loss: 9.4314
# Train Epoch: 1800 [1044/2936 (97%)]	Loss: 10.098646
# ====> Epoch: 1800 Average train loss: 9.4416
# Train Epoch: 1850 [1044/2936 (97%)]	Loss: 9.4177369
# ====> Epoch: 1850 Average train loss: 9.4278
# Train Epoch: 1900 [1044/2936 (97%)]	Loss: 9.0684428
# ====> Epoch: 1900 Average train loss: 9.4210
# Train Epoch: 1950 [1044/2936 (97%)]	Loss: 10.466683
# ====> Epoch: 1950 Average train loss: 9.4490

# %%
plt.plot(np.log(trainer.train_losses))
plt.xlabel("epochs")
plt.ylabel("log train loss")
plt.title('Log-train loss vs epochs')
plt.show()

# %%
data_t = wt(data)
recon = wt.inverse(data_t)

print("Reconstruction error={:.5f}".format(torch.norm(recon - data)**2/data.size(0)))

# get 2d wavelet filters
filt = get_1dfilts(wt)
# Out:
# Reconstruction error=0.10730

# %%
# plot original and reconstruction images
plot_1dreconstruct(data, recon)

# %% [markdown]
# ## test error

# %%
loss_v = get_loss_f(lamSum=1, lamL2norm=1, lamCMF=1, lamL1wave=1, lamL1attr=1)

# validator 
validator = Validator(model, wt, Attributer, loss_v, target=0, attr_methods='Saliency', device=device)
_, rec_loss, sum_loss, L2norm_loss, CMF_loss, L1wave_loss, L1attr_loss = validator(test_loader)

# original wavelet transform
wt_o = DWT1d(wave='db5', mode='symmetric', J=5, init_factor=1, noise_factor=0).to(device)
validator_o = Validator(model, wt_o, Attributer, loss_v, target=0, attr_methods='Saliency', device=device)
_, rec_loss_o, sum_loss_o, L2norm_loss_o, CMF_loss_o, L1wave_loss_o, L1attr_loss_o = validator_o(test_loader)

print("\n\n \t Original filter:Reconstruction Error={:.5f} sum loss={:.5f} L2norm loss={:.5f} CMF loss={:.5f} L1wave loss={:.5f} L1attribution loss={:.5f} \n \
        Adaptive filter:Reconstruction Error={:.5f} sum loss={:.5f} L2norm loss={:.5f} CMF loss={:.5f} L1wave loss={:.5f} L1attribution loss={:.5f}"\
          .format(rec_loss_o, sum_loss_o, L2norm_loss_o, CMF_loss_o, L1wave_loss_o, L1attr_loss_o, 
                  rec_loss, sum_loss, L2norm_loss, CMF_loss, L1wave_loss, L1attr_loss))
# Out:
# Test: [50/1005 (91%)]	Loss: 7.9245427
#
#  	 Original filter:Reconstruction Error=0.00000 sum loss=0.00000 L2norm loss=0.00000 CMF loss=0.00000 L1wave loss=8.85366 L1attribution loss=0.37044
#          Adaptive filter:Reconstruction Error=0.08915 sum loss=0.13713 L2norm loss=0.00028 CMF loss=0.00115 L1wave loss=8.10200 L1attribution loss=0.46132

# %%
# plot wavelet filters
filt = get_1dfilts(wt)
plot_1dfilts(filt, figsize=(1,1))

# %%
# plot original wavelet filters
filt_o = get_1dfilts(wt_o)
plot_1dfilts(filt_o, figsize=(1,1))
