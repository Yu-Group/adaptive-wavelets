# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os,sys
opj = os.path.join
from copy import deepcopy
import pickle as pkl

sys.path.append('../../src')
sys.path.append('../../src/dsets/cosmology')
from dset import get_dataloader
from viz import viz_im_r, cshow, viz_filters
from sim_cosmology import p, load_dataloader_and_pretrained_model
from losses import get_loss_f
from train import Trainer

# trim modules
sys.path.append('../../lib/trim')
from trim import TrimModel

# wt modules
from wavelet_transform import Wavelet_Transform, Attributer, get_2dfilts, initialize_filters
from utils import tuple_L1Loss, tuple_L2Loss, thresh_attrs, viz_list
from pytorch_wavelets import DTCWTForward, DTCWTInverse, DWTForward, DWTInverse
import pywt

# %% [markdown]
# ## load data and model

# %%
# get dataloader and model
(train_loader, test_loader), model = load_dataloader_and_pretrained_model(p, img_size=256)
torch.manual_seed(p.seed)
im = iter(test_loader).next()[0][0:64].to(device)

# %% [markdown]
# ## initialize filter

# %%
# wavelet transform with initialization
wt_orig = Wavelet_Transform(biort='near_sym_b', qshift='qshift_b', J=4)
viz_im_r(im[0], wt_orig.inverse(wt_orig(im))[0])
print("Recon={:.5f}".format(torch.norm(wt_orig.inverse(wt_orig(im)) - im)**2/im.size(0)))
# Out:
# Recon=0.00000

# %%
wt = initialize_filters(wt_orig, noise_level=0.1)
(fl_filt_reals, fl_filt_imags), (sl_filt_reals, sl_filt_imags) = get_2dfilts(wt, wt_type='DTCWT')
viz_im_r(im[0], wt.inverse(wt(im))[0])
print("Recon={:.5f}".format(torch.norm(wt.inverse(wt(im)) - im)**2/im.size(0)))
# Out:
# Recon=20.33313

# %%
viz_list(fl_filt_reals)
viz_list(fl_filt_imags)

# %%
viz_list(sl_filt_reals)
viz_list(sl_filt_imags)

# %% [markdown]
# ## optimize filter

# %%
# train
params = list(wt.xfm.parameters()) + list(wt.ifm.parameters())
optimizer = torch.optim.SGD(params, lr=0.00001)
loss_f = get_loss_f(lamL1attr=10, lamL1Maxattr=0)
trainer = Trainer(model, wt, Attributer, optimizer, loss_f, device=device)
trainer(train_loader, epochs=60)
# Out:
# Starting Training Loop...
# Train Epoch: 0 [15600/25000 (100%)]	Loss: 21.903502
# ====> Epoch: 0 Average train loss: 28.5517
# Train Epoch: 1 [15600/25000 (100%)]	Loss: 16.736992
# ====> Epoch: 1 Average train loss: 18.7773
# Train Epoch: 2 [15600/25000 (100%)]	Loss: 12.264243
# ====> Epoch: 2 Average train loss: 15.0561
# Train Epoch: 3 [15600/25000 (100%)]	Loss: 14.626348
# ====> Epoch: 3 Average train loss: 13.0560
# Train Epoch: 4 [15600/25000 (100%)]	Loss: 11.859594
# ====> Epoch: 4 Average train loss: 11.7623
# Train Epoch: 5 [15600/25000 (100%)]	Loss: 10.662708
# ====> Epoch: 5 Average train loss: 10.8601
# Train Epoch: 6 [15600/25000 (100%)]	Loss: 9.928619
# ====> Epoch: 6 Average train loss: 10.1977
# Train Epoch: 7 [15600/25000 (100%)]	Loss: 9.775113
# ====> Epoch: 7 Average train loss: 9.6914
# Train Epoch: 8 [15600/25000 (100%)]	Loss: 9.565180
# ====> Epoch: 8 Average train loss: 9.2904
# ====> Epoch: 36 Average train loss: 6.7303
# Train Epoch: 37 [15600/25000 (100%)]	Loss: 6.890157
# ====> Epoch: 37 Average train loss: 6.7109
# Train Epoch: 38 [15600/25000 (100%)]	Loss: 5.535259
# ====> Epoch: 38 Average train loss: 6.6919
# Train Epoch: 39 [15600/25000 (100%)]	Loss: 6.812161
# ====> Epoch: 39 Average train loss: 6.6764
# Train Epoch: 40 [15600/25000 (100%)]	Loss: 6.786893
# ====> Epoch: 40 Average train loss: 6.6606
# Train Epoch: 41 [15600/25000 (100%)]	Loss: 7.357590
# ====> Epoch: 41 Average train loss: 6.6460
# Train Epoch: 42 [15600/25000 (100%)]	Loss: 7.019698
# ====> Epoch: 42 Average train loss: 6.6314
# Train Epoch: 43 [15600/25000 (100%)]	Loss: 7.050539
# ====> Epoch: 43 Average train loss: 6.6178
# Train Epoch: 44 [15600/25000 (100%)]	Loss: 6.248092
# ====> Epoch: 44 Average train loss: 6.6040
# Train Epoch: 45 [15600/25000 (100%)]	Loss: 6.694244
# ====> Epoch: 45 Average train loss: 6.5921
# Train Epoch: 46 [15600/25000 (100%)]	Loss: 6.741701
# ====> Epoch: 46 Average train loss: 6.5802
# Train Epoch: 47 [15600/25000 (100%)]	Loss: 6.711052
# ====> Epoch: 47 Average train loss: 6.5689
# Train Epoch: 48 [15600/25000 (100%)]	Loss: 6.492056
# ====> Epoch: 48 Average train loss: 6.5578
# Train Epoch: 49 [15600/25000 (100%)]	Loss: 5.919754
# ====> Epoch: 49 Average train loss: 6.5468
# Train Epoch: 50 [15600/25000 (100%)]	Loss: 6.340013
# ====> Epoch: 50 Average train loss: 6.5372
# Train Epoch: 51 [15600/25000 (100%)]	Loss: 7.120636
# ====> Epoch: 51 Average train loss: 6.5284
# Train Epoch: 52 [15600/25000 (100%)]	Loss: 6.602228
# ====> Epoch: 52 Average train loss: 6.5186
# Train Epoch: 53 [15600/25000 (100%)]	Loss: 6.226451
# ====> Epoch: 53 Average train loss: 6.5094
# Train Epoch: 54 [15600/25000 (100%)]	Loss: 6.584824
# ====> Epoch: 54 Average train loss: 6.5012
# Train Epoch: 55 [15600/25000 (100%)]	Loss: 6.740895
# ====> Epoch: 55 Average train loss: 6.4931
# Train Epoch: 56 [15600/25000 (100%)]	Loss: 8.271242
# ====> Epoch: 56 Average train loss: 6.4866
# Train Epoch: 57 [15600/25000 (100%)]	Loss: 6.861194
# ====> Epoch: 57 Average train loss: 6.4775
# Train Epoch: 58 [15600/25000 (100%)]	Loss: 7.247355
# ====> Epoch: 58 Average train loss: 6.4705
# Train Epoch: 59 [15600/25000 (100%)]	Loss: 6.851651
# ====> Epoch: 59 Average train loss: 6.4629

# %%
plt.plot(trainer.train_losses)

# %%
(fl_filt_reals, fl_filt_imags), (sl_filt_reals, sl_filt_imags) = get_2dfilts(wt, wt_type='DTCWT')
viz_im_r(im[0], wt.inverse(wt(im))[0])
print("Recon={:.5f}".format(torch.norm(wt.inverse(wt(im)) - im)**2/im.size(0)))
# Out:
# Recon=2.44578

# %%
viz_list(fl_filt_reals)
viz_list(fl_filt_imags)

# %%
viz_list(sl_filt_reals)
viz_list(sl_filt_imags)
