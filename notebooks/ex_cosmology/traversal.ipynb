# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import random
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import os,sys
opj = os.path.join
from tqdm import tqdm
from random import randint
from copy import deepcopy
import pickle as pkl
import argparse

sys.path.append('../../src')
sys.path.append('../../src/vae')
sys.path.append('../../src/vae/models')
sys.path.append('../../src/dsets/cosmology')
from dset import get_dataloader
from model import init_specific_model
from losses import get_loss_f
from training import Trainer
from viz import viz_im_r

sys.path.append('../../lib/trim')
# trim modules
from trim import DecoderEncoder

# %%
class p:
    '''Parameters for cosmology data
    '''
    # parameters for generating data
    seed = 13
    data_path = "../../src/dsets/cosmology/data"
    
    # parameters for model architecture
    model_type = "Burgess"
    latent_dim = 10 
    img_size = (1, 64, 64)
    
    # parameters for training
    train_batch_size = 64
    test_batch_size = 100
    lr = 1e-4
    rec_dist = "gaussian"
    reg_anneal = 0
    num_epochs = 100
    
    # hyperparameters for loss
    beta = 0.0001
    lamPT = 0.0
    lamNN = 0.0
    lamH = 0.0
    lamSP = 0.0
    
    # parameters for exp
    warm_start = None # which parameter to warm start with respect to
    seq_init = 1      # value of warm_start parameter to start with respect to
    
    # SAVE MODEL
    out_dir = "/home/ubuntu/local-vae/notebooks/ex_cosmology/results" # wooseok's setup
#     out_dir = '/scratch/users/vision/chandan/local-vae' # chandan's setup
    dirname = "vary"
    pid = ''.join(["%s" % randint(0, 9) for num in range(0, 10)])

    def _str(self):
        vals = vars(p)
        return 'beta=' + str(vals['beta']) + '_lamPT=' + str(vals['lamPT']) + '_lamNN=' + str(vals['lamNN']) + '_lamSP=' + str(vals['lamSP']) \
                + '_seed=' + str(vals['seed']) + '_pid=' + vals['pid']
    
    def _dict(self):
        return {attr: val for (attr, val) in vars(self).items()
                 if not attr.startswith('_')}

# %% [markdown]
# ## VAE on cosmology data

# %%
# create dir
out_dir = opj(p.out_dir, p.dirname)
os.makedirs(out_dir, exist_ok=True)  

# seed
random.seed(p.seed)
np.random.seed(p.seed)
torch.manual_seed(p.seed)

# get dataloaders
train_loader = get_dataloader(p.data_path, 
                              batch_size=p.train_batch_size)

# prepare model
model = init_specific_model(model_type=p.model_type, 
                            img_size=p.img_size,
                            latent_dim=p.latent_dim,
                            hidden_dim=None).to(device)

# train
optimizer = torch.optim.Adam(model.parameters(), lr=p.lr)
loss_f = get_loss_f(decoder=model.decoder, **vars(p))
trainer = Trainer(model, optimizer, loss_f, device=device)

# %%
trainer(train_loader, epochs=p.num_epochs)
# Out:
# ====> Epoch: 0 Average train loss: 115.4730
# ====> Epoch: 1 Average train loss: 1.3254
# ====> Epoch: 2 Average train loss: 1.2254
# ====> Epoch: 3 Average train loss: 1.2133
# ====> Epoch: 4 Average train loss: 1.2074
# ====> Epoch: 5 Average train loss: 1.2046
# ====> Epoch: 6 Average train loss: 1.2028
# ====> Epoch: 62 Average train loss: 0.9758
# ====> Epoch: 63 Average train loss: 0.9746
# ====> Epoch: 64 Average train loss: 0.9733
# ====> Epoch: 65 Average train loss: 0.9724
# ====> Epoch: 66 Average train loss: 0.9712
# ====> Epoch: 67 Average train loss: 0.9704
# ====> Epoch: 68 Average train loss: 0.9693
# ====> Epoch: 69 Average train loss: 0.9682
# ====> Epoch: 70 Average train loss: 0.9675
# ====> Epoch: 71 Average train loss: 0.9665
# ====> Epoch: 72 Average train loss: 0.9656
# ====> Epoch: 73 Average train loss: 0.9647
# ====> Epoch: 74 Average train loss: 0.9640
# ====> Epoch: 75 Average train loss: 0.9631
# ====> Epoch: 76 Average train loss: 0.9624
# ====> Epoch: 77 Average train loss: 0.9615
# ====> Epoch: 78 Average train loss: 0.9610
# ====> Epoch: 79 Average train loss: 0.9602
# ====> Epoch: 80 Average train loss: 0.9594
# ====> Epoch: 81 Average train loss: 0.9589
# ====> Epoch: 82 Average train loss: 0.9581
# ====> Epoch: 83 Average train loss: 0.9575
# ====> Epoch: 84 Average train loss: 0.9570
# ====> Epoch: 85 Average train loss: 0.9561
# ====> Epoch: 86 Average train loss: 0.9554
# ====> Epoch: 87 Average train loss: 0.9549
# ====> Epoch: 88 Average train loss: 0.9544
# ====> Epoch: 89 Average train loss: 0.9537
# ====> Epoch: 90 Average train loss: 0.9532
# ====> Epoch: 91 Average train loss: 0.9526
# ====> Epoch: 92 Average train loss: 0.9519
# ====> Epoch: 93 Average train loss: 0.9514
# ====> Epoch: 94 Average train loss: 0.9510
# ====> Epoch: 95 Average train loss: 0.9503
# ====> Epoch: 96 Average train loss: 0.9499
# ====> Epoch: 97 Average train loss: 0.9494
# ====> Epoch: 98 Average train loss: 0.9489
# ====> Epoch: 99 Average train loss: 0.9484

# %%
im = iter(train_loader).next()[0].to(device)
recon_data, latent_dist, latent_sample = model(im)
viz_im_r(im[0,0], recon_data[0,0])
torch.save(model.state_dict(), 'results/vae.pth')

# %%
from scipy import stats
from visualize import Visualizer
import torch.nn.functional as F
from visualize import make_grid_img, get_samples
from torchvision.utils import make_grid

# %%
model_dir = opj('results/cosmo')
model.eval()  # don't sample from latent: use mean
viz = Visualizer(model=model,
                 model_dir=model_dir,
                 save_images=False)
n_rows = 10
n_cols = 10
size = (n_rows, n_cols)
num_samples = n_rows * n_cols
samples = get_samples(train_loader.dataset, num_samples)

# %%
a = viz.traversals(data=samples[0:1, ...],
               n_per_latent=n_cols,
               n_latents=n_rows,
               is_force_return=True)

# %%
plt.figure(figsize=(10,10))
plt.imshow(a, cmap='magma')
plt.axis('off')
plt.show()
